# %%
import pandas as pd

# %%
cust=pd.read_csv('Customers.csv')   # create csv file and print
print(cust)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19                NaN                      39
# 1              2    Male   21            35000.0                      81
# 2              3  Female   20                NaN                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
print(cust.head(10))
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19                NaN                      39
# 1           2    Male   21            35000.0                      81
# 2           3  Female   20                NaN                       6
# 3           4  Female   23            59000.0                      77
# 4           5  Female   31            38000.0                      40
# 5           6  Female   22            58000.0                      76
# 6           7  Female   35            31000.0                       6
# 7           8  Female   23            84000.0                      94
# 8           9    Male   64            97000.0                       3
# 9          10  Female   30            98000.0                      72
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2            NaN                1            1
# ...

# %%
cust.sort_values(["Age"],ascending=0)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1103        1104  Female   99             103706                      50
# 1524        1525  Female   99             150782                      18
# 1629        1630    Male   99             162762                      52
# 361          362    Male   99              63364                      61
# 1322        1323  Female   99             144176                      74
# ...          ...     ...  ...                ...                     ...
# 1271        1272  Female    0              61228                      81
# 559          560    Male    0             151298                      89
# 1583        1584  Female    0             120899                       7
# 211          212  Female    0              22000                      92
# 1248        1249  Female    0             143082                      63
#
#          Profession  Work Experience  Family Size
# ...

# %%
cust.sort_values(["Age"],ascending=1)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 443          444  Female    0              68761                      16
# 466          467    Male    0             186002                      80
# 1271        1272  Female    0              61228                      81
# 1248        1249  Female    0             143082                      63
# 1583        1584  Female    0             120899                       7
# ...          ...     ...  ...                ...                     ...
# 1629        1630    Male   99             162762                      52
# 1188        1189  Female   99             122548                      14
# 351          352    Male   99             173394                       4
# 361          362    Male   99              63364                      61
# 347          348  Female   99             184426                      41
#
#          Profession  Work Experience  Family Size
# ...

# %%
new_cust=cust.dropna()
print(cust)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19                NaN                      39
# 1              2    Male   21            35000.0                      81
# 2              3  Female   20                NaN                       6
# 3              4  Female   23            59000.0                      77
# 4              5  Female   31            38000.0                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71           184387.0                      40
# 1996        1997  Female   91            73158.0                      32
# 1997        1998    Male   87            90961.0                      14
# 1998        1999    Male   77           182109.0                       4
# 1999        2000    Male   90           110610.0                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
median=cust["balance"].median()
print("Median is: ",median)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'balance'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
median=cust["Annual Income ($)"].median()
print("Median is: ",median)
# Out:
# Median is:  110252.0

# %%
mean=cust["Annual Income ($)"].mean()
print("Median is: ",mean)
# Out:
# Median is:  110792.11361361362
